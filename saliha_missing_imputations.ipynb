# %%
import pandas as pd
import numpy as np
import os
import ssl                                        
ssl._create_default_https_context = ssl._create_unverified_context
from geopy.geocoders import Nominatim
df_fire = pd.read_csv("sampled_dataset.csv")
df_fire
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 0           46487                    FS
# 1          242377                   BLM
# 2           49259                    FS
# 3           50588                    FS
# 4          222205                   BLM
# ...           ...                   ...
# 376096  300286438                ST/C&L
# 376097  300287009                ST/C&L
# 376098  300307593                ST/C&L
# 376099  300288242                ST/C&L
# 376100  300285954                ST/C&L
#
#                             SOURCE_REPORTING_UNIT_NAME  \
# 0                       Salmon-Challis National Forest
# 1                            Rock Springs Field Office
# 2                       Shasta-Trinity National Forest
# 3                              Malheur National Forest
# 4                                  Susanville District
# ...                                                ...
# 376096  Arizona State Forestry Division - State Office
# 376097                       San Mateo-Santa Cruz Unit
# 376098                                      Butte Unit
# 376099  Arizona State Forestry Division - State Office
# 376100  Arizona State Forestry Division - State Office
#
#                         FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_TIME  \
# 0                             NaN       1992     1992-06-20          1035.0
# 1                      MARYSFIRST       1992     1992-08-21          1428.0
# 2                             NaN       1992     1992-06-24          1135.0
# 3                             NaN       1992     1992-08-01          1538.0
# 4                           HORSE       1992     1992-06-28          1100.0
# ...                           ...        ...            ...             ...
# 376096                     154356       2015     2015-03-16             NaN
# 376097                        NaN       2015     2015-04-23          1321.0
# 376098  18TH ST / OROVILLE DAM BL       2015     2015-08-12          1246.0
# 376099                     153500       2015     2015-07-11             NaN
# 376100                     15-015       2015     2015-01-25          1255.0
#
#         STAT_CAUSE_CODE   STAT_CAUSE_DESCR   CONT_DATE  CONT_TIME  FIRE_SIZE  \
# 0                   1.0          Lightning  1992-06-20     1336.0        0.1
# 1                   1.0          Lightning  1992-08-22     1800.0        0.1
# 2                   1.0          Lightning  1992-06-24     1800.0        0.1
# 3                   1.0          Lightning  1992-08-01     2200.0        0.1
# 4                   1.0          Lightning  1992-06-28     1324.0        0.1
# ...                 ...                ...         ...        ...        ...
# 376096             13.0  Missing/Undefined  2015-03-16     1800.0        0.1
# 376097             13.0  Missing/Undefined  2015-04-23     1334.0        1.0
# 376098             13.0  Missing/Undefined  2015-08-12     1300.0        0.1
# 376099             13.0  Missing/Undefined  2015-07-11     1800.0        0.1
# 376100             13.0  Missing/Undefined  2015-01-25     1800.0        0.1
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE            OWNER_DESCR STATE  \
# 0                    A  45.308333 -114.475000                   USFS    ID
# 1                    A  41.416600 -109.234000                    BLM    WY
# 2                    A  40.730000 -122.475000                   USFS    CA
# 3                    A  44.296667 -118.738333                   USFS    OR
# 4                    A  40.666600 -120.484400                    BLM    CA
# ...                ...        ...         ...                    ...   ...
# 376096               A  33.493680 -112.277619  MISSING/NOT SPECIFIED    AZ
# 376097               B  37.414050 -122.193200  MISSING/NOT SPECIFIED    CA
# 376098               A  39.501869 -121.605211  MISSING/NOT SPECIFIED    CA
# 376099               A  32.230100 -110.798700  MISSING/NOT SPECIFIED    AZ
# 376100               A  34.255000 -109.692500  MISSING/NOT SPECIFIED    AZ
#
#            COUNTY
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 376096        NaN
# 376097  SAN MATEO
# 376098      BUTTE
# 376099        NaN
# 376100        NaN
#
# [376101 rows x 18 columns]

# %%
df_fire.isnull().sum()
# Out:
# FOD_ID                             0
# NWCG_REPORTING_AGENCY              0
# SOURCE_REPORTING_UNIT_NAME         0
# FIRE_NAME                     192151
# FIRE_YEAR                          0
# DISCOVERY_DATE                     0
# DISCOVERY_TIME                176408
# STAT_CAUSE_CODE                    0
# STAT_CAUSE_DESCR                   0
# CONT_DATE                     178211
# CONT_TIME                     194334
# FIRE_SIZE                          0
# FIRE_SIZE_CLASS                    0
# LATITUDE                           0
# LONGITUDE                          0
# OWNER_DESCR                        0
# STATE                              0
# COUNTY                        135724
# dtype: int64

# %%
#getting rows where county is null from the dataset
df_fire_null_county = df_fire.loc[pd.isna(df_fire['COUNTY'])]
df_fire_null_county.shape
# Out:
# (135724, 18)

# %%
#those with digits records
df_not_null = df_fire.loc[pd.notnull(df_fire['COUNTY'])]
df_digit = df_not_null.loc[df_not_null['COUNTY'].str.isdigit()]
df_digit
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY     SOURCE_REPORTING_UNIT_NAME  \
# 28         130350                    FS     Clearwater National Forest
# 49         860863                ST/C&L                      Lake Unit
# 63        1396223                ST/C&L                    Dallas Unit
# 91        1397802                ST/C&L                   Klamath Unit
# 100        848767                ST/C&L                  John Day Unit
# ...           ...                   ...                            ...
# 374713  300156887                ST/C&L         Florida Forest Service
# 374714  300150168                ST/C&L  Oklahoma Division of Forestry
# 374732  300150041                ST/C&L                   Ellis County
# 374777  300150384                ST/C&L            Pottawatomie County
# 374790  300150178                ST/C&L   Arkansas Forestry Commission
#
#                   FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_TIME  \
# 28               RUBY CREEK       1992     1992-07-20          2015.0
# 49                      DOG       1992     1992-05-07             NaN
# 63           W. FORK AGENCY       1992     1992-07-20             NaN
# 91                 DEER BED       1992     1992-06-23             NaN
# 100             BOARD CREEK       1992     1992-07-25             NaN
# ...                     ...        ...            ...             ...
# 374713           OWENS ROAD       2014     2014-11-04          1245.0
# 374714          BENSON PARK       2014     2014-01-29          1230.0
# 374732  170TH AND HOMESTEAD       2014     2014-03-15          2030.0
# 374777           ELM SLOUGH       2014     2014-03-30          1350.0
# 374790           DUSTY LANE       2014     2014-02-24          1315.0
#
#         STAT_CAUSE_CODE   STAT_CAUSE_DESCR   CONT_DATE  CONT_TIME  FIRE_SIZE  \
# 28                  1.0          Lightning  1992-07-20     2231.0        0.1
# 49                  1.0          Lightning  1992-05-07        NaN        0.1
# 63                  1.0          Lightning  1992-07-20        NaN        0.1
# 91                  1.0          Lightning  1992-06-23        NaN        0.2
# 100                 1.0          Lightning  1992-07-25        NaN        0.3
# ...                 ...                ...         ...        ...        ...
# 374713             13.0  Missing/Undefined         NaN        NaN       10.0
# 374714             13.0  Missing/Undefined         NaN        NaN      132.0
# 374732             13.0  Missing/Undefined         NaN        NaN     1200.0
# 374777             13.0  Missing/Undefined         NaN        NaN      350.0
# 374790             13.0  Missing/Undefined         NaN        NaN       40.0
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE      OWNER_DESCR STATE COUNTY
# 28                   A  46.912778 -116.680556             USFS    ID     57
# 49                   A  42.108120 -120.670870          PRIVATE    OR     37
# 63                   A  45.150620 -123.690450          PRIVATE    OR     36
# 91                   A  42.125060 -122.174100          PRIVATE    OR     18
# 100                  B  45.097830 -119.573260          PRIVATE    OR     49
# ...                ...        ...         ...              ...   ...    ...
# 374713               C  30.561389  -81.541111            STATE    FL    089
# 374714               D  35.287778  -96.823056            STATE    OK    125
# 374732               F  39.045833  -99.473333  MUNICIPAL/LOCAL    KS    051
# 374777               E  39.231944  -96.440556  MUNICIPAL/LOCAL    KS    149
# 374790               C  35.882222  -91.510000          PRIVATE    AR    063
#
# [30197 rows x 18 columns]

# %% [markdown]
# ## Imputing COUNTY using Geopy package

# %%
#using latitude and longitude to find the county.
geolocator = Nominatim(user_agent="saliha_missingimputation")
list_county=[] # alternative storage of county
def location(row):
    location = geolocator.reverse(str(row.LATITUDE)+', '+str(row.LONGITUDE),timeout=None)
    try:
        list_county.append(location.raw['address']['county'])
        #print(location.raw['address']['county'])
        return location.raw['address']['county']
    except:
        list_county.append("error")
        #print("eror")
        return 'error;'
        
df_fire_null_county['COUNTY']=df_fire_null_county.apply(lambda x: location(x) ,axis=1)

# %%
df_fire_null_county.to_csv('df_fire_null_county.csv',index=False) #storing imputed county records in csv for future reference

# %%
df_fire_null_county
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 0           46487                    FS
# 1          242377                   BLM
# 2           49259                    FS
# 3           50588                    FS
# 4          222205                   BLM
# ...           ...                   ...
# 135719  300209165                   BLM
# 135720  300209174                   BLM
# 135721  300286438                ST/C&L
# 135722  300288242                ST/C&L
# 135723  300285954                ST/C&L
#
#                             SOURCE_REPORTING_UNIT_NAME   FIRE_NAME  FIRE_YEAR  \
# 0                       Salmon-Challis National Forest         NaN       1992
# 1                            Rock Springs Field Office  MARYSFIRST       1992
# 2                       Shasta-Trinity National Forest         NaN       1992
# 3                              Malheur National Forest         NaN       1992
# 4                                  Susanville District       HORSE       1992
# ...                                                ...         ...        ...
# 135719                     Central California District       RANCH       2015
# 135720                     Central California District       APPLE       2015
# 135721  Arizona State Forestry Division - State Office      154356       2015
# 135722  Arizona State Forestry Division - State Office      153500       2015
# 135723  Arizona State Forestry Division - State Office      15-015       2015
#
#        DISCOVERY_DATE  DISCOVERY_TIME  STAT_CAUSE_CODE   STAT_CAUSE_DESCR  \
# 0          1992-06-20          1035.0              1.0          Lightning
# 1          1992-08-21          1428.0              1.0          Lightning
# 2          1992-06-24          1135.0              1.0          Lightning
# 3          1992-08-01          1538.0              1.0          Lightning
# 4          1992-06-28          1100.0              1.0          Lightning
# ...               ...             ...              ...                ...
# 135719     2015-06-19          1911.0             13.0  Missing/Undefined
# 135720     2015-07-05          1500.0             13.0  Missing/Undefined
# 135721     2015-03-16             NaN             13.0  Missing/Undefined
# 135722     2015-07-11             NaN             13.0  Missing/Undefined
# 135723     2015-01-25          1255.0             13.0  Missing/Undefined
#
#          CONT_DATE  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0       1992-06-20     1336.0        0.1               A  45.308333
# 1       1992-08-22     1800.0        0.1               A  41.416600
# 2       1992-06-24     1800.0        0.1               A  40.730000
# 3       1992-08-01     2200.0        0.1               A  44.296667
# 4       1992-06-28     1324.0        0.1               A  40.666600
# ...            ...        ...        ...             ...        ...
# 135719  2015-06-19     2200.0        2.5               B  35.686400
# 135720  2015-07-05     1800.0        3.0               B  35.115300
# 135721  2015-03-16     1800.0        0.1               A  33.493680
# 135722  2015-07-11     1800.0        0.1               A  32.230100
# 135723  2015-01-25     1800.0        0.1               A  34.255000
#
#          LONGITUDE            OWNER_DESCR STATE             COUNTY
# 0      -114.475000                   USFS    ID       Lemhi County
# 1      -109.234000                    BLM    WY  Sweetwater County
# 2      -122.475000                   USFS    CA      Shasta County
# 3      -118.738333                   USFS    OR       Grant County
# 4      -120.484400                    BLM    CA      Lassen County
# ...            ...                    ...   ...                ...
# 135719 -118.578900                PRIVATE    CA        Kern County
# 135720 -118.668600                PRIVATE    CA        Kern County
# 135721 -112.277619  MISSING/NOT SPECIFIED    AZ    Maricopa County
# 135722 -110.798700  MISSING/NOT SPECIFIED    AZ        Pima County
# 135723 -109.692500  MISSING/NOT SPECIFIED    AZ      Apache County
#
# [135724 rows x 18 columns]

# %%
df_fire_null_county['COUNTY'].isnull().sum()
# Out:
# 0

# %%
mapping = dict(zip(df_fire_null_county.FOD_ID,df_fire_null_county.COUNTY))
df_fire.COUNTY = df_fire.COUNTY.fillna(df_fire.FOD_ID.map(mapping))

# %%
df_fire.to_csv('saliha_sampled_data.csv',index=False)
df_fire

# %%
df_digit['COUNTY']=df_digit.apply(lambda x: location(x) ,axis=1)
# Out:
# <ipython-input-63-7e2beef5a1de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_digit['COUNTY']=df_digit.apply(lambda x: location(x) ,axis=1)

# %%
df_digit.to_csv("digit_county_data.csv")

# %%
df_digit
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY     SOURCE_REPORTING_UNIT_NAME  \
# 28         130350                    FS     Clearwater National Forest
# 49         860863                ST/C&L                      Lake Unit
# 63        1396223                ST/C&L                    Dallas Unit
# 91        1397802                ST/C&L                   Klamath Unit
# 100        848767                ST/C&L                  John Day Unit
# ...           ...                   ...                            ...
# 374713  300156887                ST/C&L         Florida Forest Service
# 374714  300150168                ST/C&L  Oklahoma Division of Forestry
# 374732  300150041                ST/C&L                   Ellis County
# 374777  300150384                ST/C&L            Pottawatomie County
# 374790  300150178                ST/C&L   Arkansas Forestry Commission
#
#                   FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_TIME  \
# 28               RUBY CREEK       1992     1992-07-20          2015.0
# 49                      DOG       1992     1992-05-07             NaN
# 63           W. FORK AGENCY       1992     1992-07-20             NaN
# 91                 DEER BED       1992     1992-06-23             NaN
# 100             BOARD CREEK       1992     1992-07-25             NaN
# ...                     ...        ...            ...             ...
# 374713           OWENS ROAD       2014     2014-11-04          1245.0
# 374714          BENSON PARK       2014     2014-01-29          1230.0
# 374732  170TH AND HOMESTEAD       2014     2014-03-15          2030.0
# 374777           ELM SLOUGH       2014     2014-03-30          1350.0
# 374790           DUSTY LANE       2014     2014-02-24          1315.0
#
#         STAT_CAUSE_CODE   STAT_CAUSE_DESCR   CONT_DATE  CONT_TIME  FIRE_SIZE  \
# 28                  1.0          Lightning  1992-07-20     2231.0        0.1
# 49                  1.0          Lightning  1992-05-07        NaN        0.1
# 63                  1.0          Lightning  1992-07-20        NaN        0.1
# 91                  1.0          Lightning  1992-06-23        NaN        0.2
# 100                 1.0          Lightning  1992-07-25        NaN        0.3
# ...                 ...                ...         ...        ...        ...
# 374713             13.0  Missing/Undefined         NaN        NaN       10.0
# 374714             13.0  Missing/Undefined         NaN        NaN      132.0
# 374732             13.0  Missing/Undefined         NaN        NaN     1200.0
# 374777             13.0  Missing/Undefined         NaN        NaN      350.0
# 374790             13.0  Missing/Undefined         NaN        NaN       40.0
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE      OWNER_DESCR STATE  \
# 28                   A  46.912778 -116.680556             USFS    ID
# 49                   A  42.108120 -120.670870          PRIVATE    OR
# 63                   A  45.150620 -123.690450          PRIVATE    OR
# 91                   A  42.125060 -122.174100          PRIVATE    OR
# 100                  B  45.097830 -119.573260          PRIVATE    OR
# ...                ...        ...         ...              ...   ...
# 374713               C  30.561389  -81.541111            STATE    FL
# 374714               D  35.287778  -96.823056            STATE    OK
# 374732               F  39.045833  -99.473333  MUNICIPAL/LOCAL    KS
# 374777               E  39.231944  -96.440556  MUNICIPAL/LOCAL    KS
# 374790               C  35.882222  -91.510000          PRIVATE    AR
#
#                      COUNTY
# 28             Latah County
# 49              Lake County
# 63           Yamhill County
# 91           Klamath County
# 100           Morrow County
# ...                     ...
# 374713        Nassau County
# 374714  Pottawatomie County
# 374732         Ellis County
# 374777  Pottawatomie County
# 374790  Independence County
#
# [30197 rows x 18 columns]

# %%
for index, row in df_digit.iterrows():
    val = row.FOD_ID
    df_fire.loc[df_fire['FOD_ID']==val,'COUNTY'] = row.COUNTY

# %%
df_fire.to_csv('sampled_dataset_final.csv',index=False)

# %%
df_fire[]
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 0           46487                    FS
# 1          242377                   BLM
# 2           49259                    FS
# 3           50588                    FS
# 4          222205                   BLM
# ...           ...                   ...
# 376096  300286438                ST/C&L
# 376097  300287009                ST/C&L
# 376098  300307593                ST/C&L
# 376099  300288242                ST/C&L
# 376100  300285954                ST/C&L
#
#                             SOURCE_REPORTING_UNIT_NAME  \
# 0                       Salmon-Challis National Forest
# 1                            Rock Springs Field Office
# 2                       Shasta-Trinity National Forest
# 3                              Malheur National Forest
# 4                                  Susanville District
# ...                                                ...
# 376096  Arizona State Forestry Division - State Office
# 376097                       San Mateo-Santa Cruz Unit
# 376098                                      Butte Unit
# 376099  Arizona State Forestry Division - State Office
# 376100  Arizona State Forestry Division - State Office
#
#                         FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_TIME  \
# 0                             NaN       1992     1992-06-20          1035.0
# 1                      MARYSFIRST       1992     1992-08-21          1428.0
# 2                             NaN       1992     1992-06-24          1135.0
# 3                             NaN       1992     1992-08-01          1538.0
# 4                           HORSE       1992     1992-06-28          1100.0
# ...                           ...        ...            ...             ...
# 376096                     154356       2015     2015-03-16             NaN
# 376097                        NaN       2015     2015-04-23          1321.0
# 376098  18TH ST / OROVILLE DAM BL       2015     2015-08-12          1246.0
# 376099                     153500       2015     2015-07-11             NaN
# 376100                     15-015       2015     2015-01-25          1255.0
#
#         STAT_CAUSE_CODE   STAT_CAUSE_DESCR   CONT_DATE  CONT_TIME  FIRE_SIZE  \
# 0                   1.0          Lightning  1992-06-20     1336.0        0.1
# 1                   1.0          Lightning  1992-08-22     1800.0        0.1
# 2                   1.0          Lightning  1992-06-24     1800.0        0.1
# 3                   1.0          Lightning  1992-08-01     2200.0        0.1
# 4                   1.0          Lightning  1992-06-28     1324.0        0.1
# ...                 ...                ...         ...        ...        ...
# 376096             13.0  Missing/Undefined  2015-03-16     1800.0        0.1
# 376097             13.0  Missing/Undefined  2015-04-23     1334.0        1.0
# 376098             13.0  Missing/Undefined  2015-08-12     1300.0        0.1
# 376099             13.0  Missing/Undefined  2015-07-11     1800.0        0.1
# 376100             13.0  Missing/Undefined  2015-01-25     1800.0        0.1
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE            OWNER_DESCR STATE  \
# 0                    A  45.308333 -114.475000                   USFS    ID
# 1                    A  41.416600 -109.234000                    BLM    WY
# 2                    A  40.730000 -122.475000                   USFS    CA
# 3                    A  44.296667 -118.738333                   USFS    OR
# 4                    A  40.666600 -120.484400                    BLM    CA
# ...                ...        ...         ...                    ...   ...
# 376096               A  33.493680 -112.277619  MISSING/NOT SPECIFIED    AZ
# 376097               B  37.414050 -122.193200  MISSING/NOT SPECIFIED    CA
# 376098               A  39.501869 -121.605211  MISSING/NOT SPECIFIED    CA
# 376099               A  32.230100 -110.798700  MISSING/NOT SPECIFIED    AZ
# 376100               A  34.255000 -109.692500  MISSING/NOT SPECIFIED    AZ
#
#                    COUNTY
# 0            Lemhi County
# 1       Sweetwater County
# 2           Shasta County
# 3            Grant County
# 4           Lassen County
# ...                   ...
# 376096    Maricopa County
# 376097          SAN MATEO
# 376098              BUTTE
# 376099        Pima County
# 376100      Apache County
#
# [376101 rows x 18 columns]
