# %%
import pandas as pd
import numpy as np
df_disc_data = pd.read_csv('missing_values_discovery_time_dataset.csv')
df_county_data = pd.read_csv('sampled_dataset_county.csv')
df_cont_data = pd.read_csv('dataset_filled_contdate_time_garima.csv')
df_original = pd.read_csv('sampled_dataset.csv')

# %%
df_original.drop(columns='FIRE_NAME',inplace=True) # removing columns since it has data mismatch and no help to estimate the values for this col

# %%
df_original.isna().sum()
# Out:
# FOD_ID                             0
# NWCG_REPORTING_AGENCY              0
# SOURCE_REPORTING_UNIT_NAME         0
# FIRE_YEAR                          0
# DISCOVERY_DATE                     0
# DISCOVERY_TIME                176408
# STAT_CAUSE_CODE                    0
# STAT_CAUSE_DESCR                   0
# CONT_DATE                     178211
# CONT_TIME                     194334
# FIRE_SIZE                          0
# FIRE_SIZE_CLASS                    0
# LATITUDE                           0
# LONGITUDE                          0
# OWNER_DESCR                        0
# STATE                              0
# COUNTY                        135724
# dtype: int64

# %% [markdown]
# ### Update Discovery Time

# %%
df_original['DISCOVERY_TIME_1'] = df_disc_data['DISCOVERY_TIME']
df_original.drop(columns=['DISCOVERY_TIME'],inplace=True)
df_original.rename(columns={'DISCOVERY_TIME_1':'DISCOVERY_TIME',},inplace=True)

# %% [markdown]
# ### Updating Cont Date and Time

# %%
df_original['CONT_DATE_1'] = df_cont_data['CONT_DATE']
df_original['CONT_TIME_1'] = df_cont_data['CONT_TIME']
df_original.drop(columns=['CONT_DATE','CONT_TIME'],inplace=True)
df_original.rename(columns={'CONT_DATE_1':'CONT_DATE','CONT_TIME_1':'CONT_TIME'},inplace=True)

# %% [markdown]
# ### Updating County

# %%
df_original['COUNTY_UPDATED'] = df_county_data['COUNTY']
df_original.drop(columns='COUNTY',inplace=True)
df_original.rename(columns={'COUNTY_UPDATED':'COUNTY'},inplace=True)
df_original
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 0           46487                    FS
# 1          242377                   BLM
# 2           49259                    FS
# 3           50588                    FS
# 4          222205                   BLM
# ...           ...                   ...
# 376096  300286438                ST/C&L
# 376097  300287009                ST/C&L
# 376098  300307593                ST/C&L
# 376099  300288242                ST/C&L
# 376100  300285954                ST/C&L
#
#                             SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR  \
# 0                       Salmon-Challis National Forest       1992
# 1                            Rock Springs Field Office       1992
# 2                       Shasta-Trinity National Forest       1992
# 3                              Malheur National Forest       1992
# 4                                  Susanville District       1992
# ...                                                ...        ...
# 376096  Arizona State Forestry Division - State Office       2015
# 376097                       San Mateo-Santa Cruz Unit       2015
# 376098                                      Butte Unit       2015
# 376099  Arizona State Forestry Division - State Office       2015
# 376100  Arizona State Forestry Division - State Office       2015
#
#        DISCOVERY_DATE  STAT_CAUSE_CODE   STAT_CAUSE_DESCR  FIRE_SIZE  \
# 0          1992-06-20              1.0          Lightning        0.1
# 1          1992-08-21              1.0          Lightning        0.1
# 2          1992-06-24              1.0          Lightning        0.1
# 3          1992-08-01              1.0          Lightning        0.1
# 4          1992-06-28              1.0          Lightning        0.1
# ...               ...              ...                ...        ...
# 376096     2015-03-16             13.0  Missing/Undefined        0.1
# 376097     2015-04-23             13.0  Missing/Undefined        1.0
# 376098     2015-08-12             13.0  Missing/Undefined        0.1
# 376099     2015-07-11             13.0  Missing/Undefined        0.1
# 376100     2015-01-25             13.0  Missing/Undefined        0.1
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE            OWNER_DESCR STATE  \
# 0                    A  45.308333 -114.475000                   USFS    ID
# 1                    A  41.416600 -109.234000                    BLM    WY
# 2                    A  40.730000 -122.475000                   USFS    CA
# 3                    A  44.296667 -118.738333                   USFS    OR
# 4                    A  40.666600 -120.484400                    BLM    CA
# ...                ...        ...         ...                    ...   ...
# 376096               A  33.493680 -112.277619  MISSING/NOT SPECIFIED    AZ
# 376097               B  37.414050 -122.193200  MISSING/NOT SPECIFIED    CA
# 376098               A  39.501869 -121.605211  MISSING/NOT SPECIFIED    CA
# 376099               A  32.230100 -110.798700  MISSING/NOT SPECIFIED    AZ
# 376100               A  34.255000 -109.692500  MISSING/NOT SPECIFIED    AZ
#
#         DISCOVERY_TIME   CONT_DATE  CONT_TIME             COUNTY
# 0                 1035  1992-06-20     1336.0       Lemhi County
# 1                 1428  1992-08-22     1800.0  Sweetwater County
# 2                 1135  1992-06-24     1800.0      Shasta County
# 3                 1538  1992-08-01     2200.0       Grant County
# 4                 1100  1992-06-28     1324.0      Lassen County
# ...                ...         ...        ...                ...
# 376096            1537  2015-03-16     1800.0    Maricopa County
# 376097            1321  2015-04-23     1334.0          SAN MATEO
# 376098            1246  2015-08-12     1300.0              BUTTE
# 376099            1382  2015-07-11     1800.0        Pima County
# 376100            1255  2015-01-25     1800.0      Apache County
#
# [376101 rows x 17 columns]

# %%
df_original.isna().sum()
# Out:
# FOD_ID                        0
# NWCG_REPORTING_AGENCY         0
# SOURCE_REPORTING_UNIT_NAME    0
# FIRE_YEAR                     0
# DISCOVERY_DATE                0
# STAT_CAUSE_CODE               0
# STAT_CAUSE_DESCR              0
# FIRE_SIZE                     0
# FIRE_SIZE_CLASS               0
# LATITUDE                      0
# LONGITUDE                     0
# OWNER_DESCR                   0
# STATE                         0
# DISCOVERY_TIME                0
# CONT_DATE                     0
# CONT_TIME                     0
# COUNTY                        0
# dtype: int64

# %%
df_original.to_csv('preprocessed_dataset.csv',index=False)

# %% [markdown]
# ### Sampling

# %%
df_fire = pd.read_csv('preprocessed_dataset.csv')
df_fire
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 0           46487                    FS
# 1          242377                   BLM
# 2           49259                    FS
# 3           50588                    FS
# 4          222205                   BLM
# ...           ...                   ...
# 376096  300286438                ST/C&L
# 376097  300287009                ST/C&L
# 376098  300307593                ST/C&L
# 376099  300288242                ST/C&L
# 376100  300285954                ST/C&L
#
#                             SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR  \
# 0                       Salmon-Challis National Forest       1992
# 1                            Rock Springs Field Office       1992
# 2                       Shasta-Trinity National Forest       1992
# 3                              Malheur National Forest       1992
# 4                                  Susanville District       1992
# ...                                                ...        ...
# 376096  Arizona State Forestry Division - State Office       2015
# 376097                       San Mateo-Santa Cruz Unit       2015
# 376098                                      Butte Unit       2015
# 376099  Arizona State Forestry Division - State Office       2015
# 376100  Arizona State Forestry Division - State Office       2015
#
#        DISCOVERY_DATE  STAT_CAUSE_CODE   STAT_CAUSE_DESCR  FIRE_SIZE  \
# 0          1992-06-20              1.0          Lightning        0.1
# 1          1992-08-21              1.0          Lightning        0.1
# 2          1992-06-24              1.0          Lightning        0.1
# 3          1992-08-01              1.0          Lightning        0.1
# 4          1992-06-28              1.0          Lightning        0.1
# ...               ...              ...                ...        ...
# 376096     2015-03-16             13.0  Missing/Undefined        0.1
# 376097     2015-04-23             13.0  Missing/Undefined        1.0
# 376098     2015-08-12             13.0  Missing/Undefined        0.1
# 376099     2015-07-11             13.0  Missing/Undefined        0.1
# 376100     2015-01-25             13.0  Missing/Undefined        0.1
#
#        FIRE_SIZE_CLASS   LATITUDE   LONGITUDE            OWNER_DESCR STATE  \
# 0                    A  45.308333 -114.475000                   USFS    ID
# 1                    A  41.416600 -109.234000                    BLM    WY
# 2                    A  40.730000 -122.475000                   USFS    CA
# 3                    A  44.296667 -118.738333                   USFS    OR
# 4                    A  40.666600 -120.484400                    BLM    CA
# ...                ...        ...         ...                    ...   ...
# 376096               A  33.493680 -112.277619  MISSING/NOT SPECIFIED    AZ
# 376097               B  37.414050 -122.193200  MISSING/NOT SPECIFIED    CA
# 376098               A  39.501869 -121.605211  MISSING/NOT SPECIFIED    CA
# 376099               A  32.230100 -110.798700  MISSING/NOT SPECIFIED    AZ
# 376100               A  34.255000 -109.692500  MISSING/NOT SPECIFIED    AZ
#
#         DISCOVERY_TIME   CONT_DATE  CONT_TIME             COUNTY
# 0                 1035  1992-06-20     1336.0       Lemhi County
# 1                 1428  1992-08-22     1800.0  Sweetwater County
# 2                 1135  1992-06-24     1800.0      Shasta County
# 3                 1538  1992-08-01     2200.0       Grant County
# 4                 1100  1992-06-28     1324.0      Lassen County
# ...                ...         ...        ...                ...
# 376096            1537  2015-03-16     1800.0    Maricopa County
# 376097            1321  2015-04-23     1334.0          SAN MATEO
# 376098            1246  2015-08-12     1300.0              BUTTE
# 376099            1382  2015-07-11     1800.0        Pima County
# 376100            1255  2015-01-25     1800.0      Apache County
#
# [376101 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split
X = df_fire.drop(columns='STAT_CAUSE_CODE')
y = df_fire['STAT_CAUSE_CODE']

# %%
X_inter,X_test,y_inter,y_test = train_test_split(X,y,shuffle=True,random_state=15,test_size=0.2)
X_train,X_valid,y_train,y_valid = train_test_split(X_inter,y_inter, shuffle=False,random_state=2018,test_size=0.25)
del X_inter, y_inter
print("train: {}% | validation: {}% | test {}%".format(round(len(y_train)/len(y),2),
                                                       round(len(y_valid)/len(y),2),
                                                       round(len(y_test)/len(y),2)))
# Out:
# train: 0.6% | validation: 0.2% | test 0.2%

# %%
train_set = X_train
train_set['STAT_CAUSE_CODE'] = y_train
train_set.to_csv('training_dataset.csv', index=False)
train_set
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 25152     1656004                ST/C&L
# 224397     973664                ST/C&L
# 225099    1167043                ST/C&L
# 340429    1455401                ST/C&L
# 143205    1052580                ST/C&L
# ...           ...                   ...
# 16531     1029822                ST/C&L
# 69348      453969                ST/C&L
# 235030     919106                ST/C&L
# 176596  201336293                ST/C&L
# 65245      284548                   BIA
#
#                     SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 25152              Georgia Forestry Commission       2002     2002-05-03
# 224397                          AFC District 4       2000     2000-02-10
# 225099                 NCS Region 2 District 6       2000     2000-04-21
# 340429                       Woodruff District       2010     2010-04-02
# 143205                              SCS Unit 6       2001     2001-12-30
# ...                                        ...        ...            ...
# 16531                               OKS Unit 4       1999     1999-08-17
# 69348                          GAS Tifton Unit       2003     2003-01-14
# 235030                  MSS Southwest District       2004     2004-09-28
# 176596  Texas Forest Service - Livingston Area       2010     2010-06-14
# 65245                          Colville Agency       2000     2000-06-04
#
#        STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 25152         Lightning      14.20               C  30.864100  -82.736100
# 224397            Arson       0.10               A  30.684200  -87.707800
# 225099            Arson       1.00               B  35.150000  -78.483300
# 340429        Powerline       0.20               A  46.027000  -89.529590
# 143205   Debris Burning       0.80               B  32.737500  -80.202800
# ...                 ...        ...             ...        ...         ...
# 16531         Lightning       5.00               B  34.091700  -95.008900
# 69348     Equipment Use       2.47               B  31.446080  -83.470885
# 235030            Arson       3.00               B  31.625300  -90.432500
# 176596   Debris Burning       1.00               B  30.230833  -94.111111
# 65245     Equipment Use      45.50               C  47.991000 -118.951100
#
#                   OWNER_DESCR STATE  DISCOVERY_TIME   CONT_DATE  CONT_TIME  \
# 25152                 PRIVATE    GA            1025  2002-05-03     1025.0
# 224397  MISSING/NOT SPECIFIED    AL            1496  2000-02-10     2030.0
# 225099  MISSING/NOT SPECIFIED    NC            1474  2000-04-21     2252.0
# 340429                PRIVATE    WI            1556  2010-04-02     2059.0
# 143205  MISSING/NOT SPECIFIED    SC            1357  2001-12-30     1558.0
# ...                       ...   ...             ...         ...        ...
# 16531   MISSING/NOT SPECIFIED    OK            1378  1999-08-18     1500.0
# 69348   MISSING/NOT SPECIFIED    GA            1614  2003-01-14     1000.0
# 235030  MISSING/NOT SPECIFIED    MS            1352  2004-09-28     1030.0
# 176596       STATE OR PRIVATE    TX            1940  2010-06-14     2213.0
# 65245                     BIA    WA            1423  2000-06-05     1600.0
#
#                    COUNTY  STAT_CAUSE_CODE
# 25152              Clinch              1.0
# 224397     Baldwin County              7.0
# 225099  Missing/Undefined              7.0
# 340429              Vilas             11.0
# 143205  Charleston County              5.0
# ...                   ...              ...
# 16531    McCurtain County              1.0
# 69348                Tift              2.0
# 235030     Lincoln County              7.0
# 176596             Orange              5.0
# 65245     Okanogan County              2.0
#
# [225660 rows x 17 columns]

# %%
valid_set = X_valid
valid_set['STAT_CAUSE_CODE'] = y_valid
valid_set.to_csv('validation_dataset.csv', index=False)
valid_set
# Out:
#            FOD_ID NWCG_REPORTING_AGENCY  \
# 29763      441010                ST/C&L
# 43779     1476722                   NPS
# 306458     698484                ST/C&L
# 28510      332031                   BLM
# 177459   19505302                ST/C&L
# ...           ...                   ...
# 104832      16455                    FS
# 180087  201414077                ST/C&L
# 199301      97909                    FS
# 270220    1470054                   BIA
# 269768    1760862                ST/C&L
#
#                          SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR DISCOVERY_DATE  \
# 29763                        Florida Forest Service       2004     2004-06-03
# 43779                    Grand Canyon National Park       2010     2010-08-04
# 306458                         Texas Forest Service       2007     2007-12-22
# 28510          Western Slope Center, Grand Junction       2003     2003-06-16
# 177459  North Carolina Division of Forest Resources       2010     2010-04-07
# ...                                             ...        ...            ...
# 104832         Mt. Baker-Snoqualmie National Forest       2006     2006-09-23
# 180087                                  Muldoon VFD       2011     2011-06-12
# 199301        Francis Marion-Sumter National Forest       1997     1997-04-03
# 270220                              Red Lake Agency       2010     2010-03-26
# 269768                  Fire Department of New York       2009     2009-03-28
#
#        STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 29763         Lightning        3.0               B  27.500560  -81.403610
# 43779         Lightning        0.1               A  36.230295 -113.047086
# 306458    Miscellaneous        1.0               B  32.890700  -95.535580
# 28510         Lightning        0.1               A  39.733300 -108.517300
# 177459   Debris Burning       25.0               C  35.305250  -78.912033
# ...                 ...        ...             ...        ...         ...
# 104832         Campfire        0.1               A  48.090556 -121.544444
# 180087   Debris Burning        1.0               B  29.788747  -97.296042
# 199301         Railroad        7.0               B  32.966667  -79.850000
# 270220         Children        0.5               B  47.872220  -95.025280
# 269768         Children        0.1               A  42.635165  -73.538032
#
#                   OWNER_DESCR STATE  DISCOVERY_TIME   CONT_DATE  CONT_TIME  \
# 29763   MISSING/NOT SPECIFIED    FL            1299  2004-06-03     1350.0
# 43779                     NPS    AZ            1720  2010-08-05     1355.0
# 306458  MISSING/NOT SPECIFIED    TX            1400  2007-12-22     2055.0
# 28510                     BLM    CO            1726  2003-06-16     2047.0
# 177459                PRIVATE    NC            1015  2010-04-07     1400.0
# ...                       ...   ...             ...         ...        ...
# 104832                   USFS    WA            1430  2006-09-23     1500.0
# 180087       STATE OR PRIVATE    TX            1496  2011-06-12     1817.0
# 199301                   USFS    SC            1300  1997-04-04     1900.0
# 270220                    BIA    MN            1230  2010-03-26     1258.0
# 269768  MISSING/NOT SPECIFIED    NY            1938  2009-03-28     1938.0
#
#                   COUNTY  STAT_CAUSE_CODE
# 29763          Highlands              1.0
# 43779      Mohave County              1.0
# 306458              Wood              9.0
# 28510               Mesa              1.0
# 177459           Harnett              5.0
# ...                  ...              ...
# 104832  Snohomish County              4.0
# 180087           Fayette              5.0
# 199301   Berkeley County              6.0
# 270220   Beltrami County              8.0
# 269768        RENSSELAER              8.0
#
# [75220 rows x 17 columns]

# %%
test_set = X_test
test_set['STAT_CAUSE_CODE'] = y_test
test_set.to_csv('test_dataset.csv', index=False)
test_set

# %%
df = df_original['LONGITUDE']

# %%
df['LATITUDE'] = df_original['LATI']
